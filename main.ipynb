# %%
import numpy as np
import pandas as pd
import numpy as np
import csv
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from IPython.display import display

# %%
dataset=[]
real_labels=[]
count=0

with open('sentiment-analysis.csv', newline='') as csvfile:
    
    reader = csv.reader(csvfile)
    
    for row in reader:
        if(count!=0):
          result=(str(row[0]).split(","))
          if(len(result)>1): 
            dataset.append(result[0])
            sentiment=result[1]
            if(sentiment[1] == 'P'):
                real_labels.append(1)
            else:
                real_labels.append(0)
            
            
                    
            
        count+=1

# %%
# vetorização dos textos
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(dataset)

# %%
# 30% do conjunto de dados é utilizado para os testes e 70% é utilizado para o treinamento
x_train, x_test, y_train, y_test = train_test_split(X, real_labels, test_size=0.3, random_state=42)

svc = SVC(kernel='linear')
svc.fit(x_train, y_train)

y_pred = svc.predict(x_test)

# avaliação do modelo
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)

labels_name = ['Negativo', 'Positivo']

# Criar um DataFrame com 16 linhas e duas colunas
data = {'Verdadeiro': ['Positivo' if i==1 else 'Negativo' for i in y_test], 'Previsto': ['Positivo' if i==1 else 'Negativo' for i in y_pred]}
df = pd.DataFrame(data)
display(df)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        11
#            1       1.00      0.89      0.94        18
#
#     accuracy                           0.93        29
#    macro avg       0.92      0.94      0.93        29
# weighted avg       0.94      0.93      0.93        29
#    Verdadeiro  Previsto
# 0    Negativo  Negativo
# 1    Positivo  Positivo
# 2    Positivo  Positivo
# 3    Negativo  Negativo
# 4    Positivo  Positivo
# 5    Positivo  Negativo
# 6    Positivo  Positivo
# 7    Positivo  Positivo
# 8    Positivo  Negativo
# 9    Positivo  Positivo
# 10   Positivo  Positivo
# 11   Negativo  Negativo
# 12   Positivo  Positivo
# 13   Positivo  Positivo
# 14   Positivo  Positivo
# 15   Positivo  Positivo
# 16   Positivo  Positivo
# 17   Negativo  Negativo
# 18   Negativo  Negativo
# 19   Positivo  Positivo
# 20   Positivo  Positivo
# 21   Negativo  Negativo
# 22   Negativo  Negativo
# 23   Positivo  Positivo
# 24   Negativo  Negativo
# 25   Negativo  Negativo
# 26   Negativo  Negativo
# 27   Negativo  Negativo
# 28   Positivo  Positivo

# %%
pred_labels=[]
k = 2  # número de clusters (positivo, negativo)
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)

labels = kmeans.labels_


sentiments = ['Positive', 'Negative']


for i, text in enumerate(dataset):
    #print(f"Texto: '{text}' -> Sentimento: {sentiments[labels[i]]}")
    sentiment=sentiments[labels[i]]
    
    if(sentiment[0].startswith('P')):
        pred_labels.append(1)
    else:
        pred_labels.append(0)       
        
print("Resultado:", adjusted_rand_score(real_labels, pred_labels))
# Out:
# Texto: '"I love this product!"' -> Sentimento: Negative
# Texto: '"The service was terrible."' -> Sentimento: Positive
# Texto: '"This movie is amazing!"' -> Sentimento: Negative
# Texto: '"I'm so disappointed with their customer support."' -> Sentimento: Positive
# Texto: '"Just had the best meal of my life!"' -> Sentimento: Positive
# Texto: '"The quality of this product is subpar."' -> Sentimento: Negative
# Texto: '"I can't stop listening to this song. It's incredible!"' -> Sentimento: Negative
# Texto: '"Their website is so user-friendly. Love it!"' -> Sentimento: Negative
# Texto: '"I loved the movie! It was fantastic!"' -> Sentimento: Negative
# Texto: '"The customer service was terrible."' -> Sentimento: Positive
# Texto: '"This book made me feel inspired. Highly recommended!"' -> Sentimento: Positive
# Texto: '"I'm extremely disappointed with their product quality."' -> Sentimento: Positive
# Texto: '"Just had the most amazing vacation! I can't wait to go back."' -> Sentimento: Negative
# Texto: '"The food at this restaurant was awful. Never going back again!"' -> Sentimento: Negative
# Texto: '"I can't stop listening to this song. It's my new favorite!"' -> Sentimento: Negative
# Texto: '"Their website is so confusing and poorly designed."' -> Sentimento: Negative
# Texto: '"I had an incredible experience at the theme park. So much fun!"' -> Sentimento: Positive
# Texto: '"The product arrived damaged. Very disappointed."' -> Sentimento: Positive
# Texto: '"The concert was absolutely breathtaking. Best performance ever!"' -> Sentimento: Positive
# Texto: '"I had a terrible experience with their customer support."' -> Sentimento: Positive
# Texto: '"This movie is a masterpiece! I was blown away."' -> Sentimento: Negative
# Texto: '"The customer service at this store is top-notch."' -> Sentimento: Negative
# Texto: '"I'm disappointed with the ending of this book. It fell flat."' -> Sentimento: Positive
# Texto: '"The product I received was damaged. Unacceptable."' -> Sentimento: Positive
# Texto: '"Just had the worst flight experience. Delayed and rude staff."' -> Sentimento: Positive
# Texto: '"The hotel stay was absolutely amazing! Luxury at its finest."' -> Sentimento: Negative
# Texto: '"The food at this restaurant was outstanding. Highly recommended!"' -> Sentimento: Negative
# Texto: '"This playlist is my go-to for workouts. Energizing and motivating!"' -> Sentimento: Negative
# Texto: '"I had a frustrating experience navigating through their website."' -> Sentimento: Positive
# Texto: '"The roller coaster ride was thrilling! Heart-pounding excitement!"' -> Sentimento: Positive
# Texto: '"The product I ordered never arrived. Terrible service."' -> Sentimento: Positive
# Texto: '"I can't get enough of this band. Their music is incredible!"' -> Sentimento: Negative
# Texto: '"I had a great chat with their customer support. Helpful and friendly."' -> Sentimento: Positive
# Texto: '"This restaurant has the most delicious food. I can't wait to go back!"' -> Sentimento: Negative
# Texto: '"The product I purchased broke within a week. Poor quality."' -> Sentimento: Positive
# Texto: '"This book is thought-provoking and beautifully written. Highly recommended!"' -> Sentimento: Negative
# Texto: '"The customer service at this store is exceptional. They went above and beyond."' -> Sentimento: Negative
# Texto: '"I had a terrible experience with their technical support. No resolution."' -> Sentimento: Positive
# Texto: '"The live concert was electrifying! The band's energy was contagious."' -> Sentimento: Positive
# Texto: '"I'm disappointed with the food at this restaurant. It was tasteless."' -> Sentimento: Negative
# Texto: '"This song always puts me in a good mood. It's my go-to feel-good track!"' -> Sentimento: Positive
# Texto: '"The website is slow and unresponsive. Difficult to navigate."' -> Sentimento: Negative
# Texto: '"The roller coaster ride was exhilarating! Pure adrenaline rush!"' -> Sentimento: Positive
# Texto: '"The product I ordered arrived damaged. Very disappointed with the packaging."' -> Sentimento: Positive
# Texto: '"I'm captivated by this band's unique sound. They're a breath of fresh air!"' -> Sentimento: Negative
# Texto: '"The customer support was quick to respond and resolved my issue. Impressed!"' -> Sentimento: Positive
# Texto: '"This restaurant has the best food. I highly recommend it!"' -> Sentimento: Negative
# Texto: '"The plot of this movie is confusing and hard to follow."' -> Sentimento: Negative
# Texto: '"I'm addicted to this game. It's so much fun!"' -> Sentimento: Negative
# Texto: '"The customer service at this hotel was terrible. Avoid at all costs."' -> Sentimento: Positive
# Texto: '"This book bored me to tears. I couldn't finish it."' -> Sentimento: Positive
# Texto: '"I'm impressed with the sound quality of these headphones. Excellent!"' -> Sentimento: Positive
# Texto: '"The website design is sleek and user-friendly. Easy to navigate."' -> Sentimento: Negative
# Texto: '"I had a terrible experience with their delivery service. Late and unprofessional."' -> Sentimento: Positive
# Texto: '"The concert was mind-blowing! The band knows how to put on a show."' -> Sentimento: Positive
# Texto: '"I'm extremely disappointed with the customer support. No resolution."' -> Sentimento: Positive
# Texto: '"The hotel staff were rude and unprofessional. Terrible customer service."' -> Sentimento: Positive
# Texto: '"The food at this restaurant was mediocre. Nothing special."' -> Sentimento: Negative
# Texto: '"This song always puts me in a nostalgic mood. It reminds me of good times."' -> Sentimento: Positive
# Texto: '"The website loading speed is frustratingly slow. Needs improvement."' -> Sentimento: Negative
# Texto: '"The food at this cafe exceeded my expectations. Absolutely delicious!"' -> Sentimento: Negative
# Texto: '"I'm disappointed with the ending of this TV show. It left too many unanswered questions."' -> Sentimento: Negative
# Texto: '"This album is a masterpiece. Every song is a work of art!"' -> Sentimento: Negative
# Texto: '"The website layout is cluttered and confusing. Difficult to find information."' -> Sentimento: Negative
# Texto: '"The roller coaster at this theme park is a thrilling experience. A must-try!"' -> Sentimento: Negative
# Texto: '"The product I ordered never arrived. Poor customer service."' -> Sentimento: Positive
# Texto: '"I'm in awe of this artist's talent. Their paintings are breathtaking!"' -> Sentimento: Negative
# Texto: '"The food at this restaurant was disappointing. Not worth the price."' -> Sentimento: Negative
# Texto: '"This playlist is perfect for relaxation. Soothing and calming!"' -> Sentimento: Negative
# Texto: '"The website navigation is smooth and intuitive. I found what I needed quickly."' -> Sentimento: Negative
# Texto: '"The ride on this cruise ship was an unforgettable experience. I loved every moment!"' -> Sentimento: Negative
# Texto: '"The product I received was of poor quality. It broke after a few uses."' -> Sentimento: Positive
# Texto: '"This book kept me hooked from start to finish. A captivating read!"' -> Sentimento: Positive
# Texto: '"The customer service at this store is outstanding. They truly care about their customers."' -> Sentimento: Negative
# Texto: '"I had a frustrating experience with their technical support. No resolution provided."' -> Sentimento: Positive
# Texto: '"The hotel staff were rude and unprofessional. Terrible customer service."' -> Sentimento: Positive
# Texto: '"The food at this restaurant was mediocre. Nothing special."' -> Sentimento: Negative
# Texto: '"This song always puts me in a nostalgic mood. It reminds me of good times."' -> Sentimento: Positive
# Texto: '"The website loading speed is frustratingly slow. Needs improvement."' -> Sentimento: Negative
# Texto: '"I love this product!"' -> Sentimento: Negative
# Texto: '"The service was terrible."' -> Sentimento: Positive
# Texto: '"This movie is amazing!"' -> Sentimento: Negative
# Texto: '"I'm so disappointed with their customer support."' -> Sentimento: Positive
# Texto: '"Just had the best meal of my life!"' -> Sentimento: Positive
# Texto: '"The quality of this product is subpar."' -> Sentimento: Negative
# Texto: '"I can't stop listening to this song. It's incredible!"' -> Sentimento: Negative
# Texto: '"Their website is so user-friendly. Love it!"' -> Sentimento: Negative
# Texto: '"I loved the movie! It was fantastic!"' -> Sentimento: Negative
# Texto: '"The customer service was terrible."' -> Sentimento: Positive
# Texto: '"This book made me feel inspired. Highly recommended!"' -> Sentimento: Positive
# Texto: '"I'm extremely disappointed with their product quality."' -> Sentimento: Positive
# Texto: '"Just had the most amazing vacation! I can't wait to go back."' -> Sentimento: Negative
# Texto: '"The food at this restaurant was awful. Never going back again!"' -> Sentimento: Negative
# Texto: '"I can't stop listening to this song. It's my new favorite!"' -> Sentimento: Negative
# Texto: '"Their website is so confusing and poorly designed."' -> Sentimento: Negative
# Texto: '"I had an incredible experience at the theme park. So much fun!"' -> Sentimento: Positive
# Resultado: 0.07544126430844786
